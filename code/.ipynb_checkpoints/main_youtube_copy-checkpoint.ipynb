# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
titanic_data = pd.read_csv('../data/train.csv')

# %%
import seaborn as sns
sns.heatmap(titanic_data.corr(), annot=True, cmap='YlGnBu', fmt=".2f")
plt.show()

# %% [markdown]
# # (A) prwto split = stratified shuffle split
# ### Θελω να σπασω (split) dataset σε train και test (πχ 70/30) και να ανακατεψω (shuffle) ΑΛΛΑ ταυτοχρονα να κρατησω σε 80/20 επιπεδα την μια κατηγορια (stratified). νομιζω default einai 80/20 xwris na tou to peis.
#
# πχ MMMMMMFFFFMMMM -> MFFMMMFMMM + MFMM
#
# εδω με ενδιαφερει το Suruvived Pclass Sex

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split_object = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_indices, test_indices in split_object.split(titanic_data, titanic_data[["Survived"]]):
    strat_train_set = titanic_data.loc[train_indices]
    strat_test_set = titanic_data.loc[test_indices]

# %% [markdown]
# ## tsekare thn katanomh sygekrimenwn kathgoriwn anamesa sta train kai test sets.
# ## thaprepe nanai idia se afta ta cats pou evala sto STRATIFIEDSHUFFLESPLIT
# ## kai PSILOtyxaia stis alles

# %%
plt.subplot(1,2,1)
strat_train_set["Age"].hist(bins=20, label="Age")
plt.legend()

plt.subplot(1,2,2)
strat_test_set["Age"].hist(bins=20, label="Age")
plt.legend()

plt.show()

# %% [markdown]
# # (B) 1 PIPELINE
# # ftiaxnw nea classες AgeImputer kai FeatureEncoder.
# # giati? ti katafernw me afta?
#
# ## AgeImputer = gemizei kena hlikias "Age" me meso oro

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer

class AgeImputer(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        imputer_instance = SimpleImputer(strategy="mean")
        X['Age'] = imputer_instance.fit_transform(X[['Age']])
        return X

# %% [markdown]
# # 2 PIPELINE
# ## FeatureEncoder = onehot encode se "embarked" kai "gender"

# %%
from sklearn.preprocessing import OneHotEncoder

class FeatureEncoder(BaseEstimator, TransformerMixin):
    
    def fit(self,X,y=None):
        return self
    
    # to idio
    # matrix = numpy array
    # antikathistw 
    
    def transform(self,X):
        encoder_instance = OneHotEncoder()
        matrix_array = encoder_instance.fit_transform(X[["Embarked"]]).toarray()
        
        
        column_names = ["Q", "S", "C", "N"]
        
        
        for i in range(len(matrix_array.T)):
            # flipparw giati thelw gia kathe grammh
            # kai kanonika kathe stoixeio tou array einai sthlh(?)
            # ftiaxnw nees sthles(?) ston X vasei tou kainourgiou pinaka(???)
            X[column_names[i]] = matrix_array.T[i]
            
        
        matrix_array = encoder_instance.fit_transform(X[['Sex']]).toarray()
        
        column_names = ["Female", "Male"]
        
        for i in range(len(matrix_array.T)):
            
            # akrivws idio giati ftiaxnw nees
            
            X[column_names[i]] = matrix_array.T[i]
        
        return X

# %% [markdown]
# # 3 PIPELINE
# ## FeatureDropper = twra kanw DROP ta features pou den thelw

# %%
class FeatureDropper(BaseEstimator, TransformerMixin):
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X):
        # axis = 1 DROP COL
        return X.drop(["Embarked", "Name", "Ticket", "Cabin", "Sex", "N"], axis=1, errors="ignore")

# %% [markdown]
# # 4 PIPELINE
#
# ## ftiaxnw pipeline

# %%
from sklearn.pipeline import Pipeline

pipeline_object = Pipeline([("ageimputer", AgeImputer()),
                            ("featureencoder", FeatureEncoder()),
                            ("featuredropper", FeatureDropper())])

# %% [markdown]
# ### TRAIN <---- pipeline

# %%
strat_train_set = pipeline_object.fit_transform(strat_train_set)

# %% [markdown]
# # (C) SPLIT input-target X-y
# ## (thelw X y data se numpy array)

# %% [markdown]
# 1. split
# 2. ftiaxnw scaler mono gia input X
# 3. fit se X

# %%
X = strat_train_set.drop(['Survived'], axis=1)
y = strat_train_set['Survived']

# %%
X
# Out:
#      PassengerId  Pclass        Age  SibSp  Parch     Fare    Q    S    C  \
# 668          483       3  50.000000      0      0   8.0500  0.0  0.0  1.0
# 786          703       3  18.000000      0      1  14.4542  1.0  0.0  0.0
# 571          288       3  22.000000      0      0   7.8958  0.0  0.0  1.0
# 761          654       3  29.507367      0      0   7.8292  0.0  1.0  0.0
# 236          123       2  32.500000      1      0  30.0708  1.0  0.0  0.0
# ..           ...     ...        ...    ...    ...      ...  ...  ...  ...
# 426           45       3  19.000000      0      0   7.8792  0.0  1.0  0.0
# 553          255       3  41.000000      0      2  20.2125  0.0  0.0  1.0
# 612          379       3  20.000000      0      0   4.0125  1.0  0.0  0.0
# 540          228       3  20.500000      0      0   7.2500  0.0  0.0  1.0
# 95           435       1  50.000000      1      0  55.9000  0.0  0.0  1.0
#
#      Female  Male
# 668     0.0   1.0
# 786     1.0   0.0
# 571     0.0   1.0
# 761     1.0   0.0
# 236     0.0   1.0
# ..      ...   ...
# 426     1.0   0.0
# 553     1.0   0.0
# 612     0.0   1.0
# 540     0.0   1.0
# 95      0.0   1.0
#
# [712 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_data = scaler.fit_transform(X)
y_data = y.to_numpy()

# %%
X
# Out:
#      PassengerId  Pclass        Age  SibSp  Parch     Fare    Q    S    C  \
# 668          483       3  50.000000      0      0   8.0500  0.0  0.0  1.0
# 786          703       3  18.000000      0      1  14.4542  1.0  0.0  0.0
# 571          288       3  22.000000      0      0   7.8958  0.0  0.0  1.0
# 761          654       3  29.507367      0      0   7.8292  0.0  1.0  0.0
# 236          123       2  32.500000      1      0  30.0708  1.0  0.0  0.0
# ..           ...     ...        ...    ...    ...      ...  ...  ...  ...
# 426           45       3  19.000000      0      0   7.8792  0.0  1.0  0.0
# 553          255       3  41.000000      0      2  20.2125  0.0  0.0  1.0
# 612          379       3  20.000000      0      0   4.0125  1.0  0.0  0.0
# 540          228       3  20.500000      0      0   7.2500  0.0  0.0  1.0
# 95           435       1  50.000000      1      0  55.9000  0.0  0.0  1.0
#
#      Female  Male
# 668     0.0   1.0
# 786     1.0   0.0
# 571     0.0   1.0
# 761     1.0   0.0
# 236     0.0   1.0
# ..      ...   ...
# 426     1.0   0.0
# 553     1.0   0.0
# 612     0.0   1.0
# 540     0.0   1.0
# 95      0.0   1.0
#
# [712 rows x 11 columns]

# %% [markdown]
# # (D) MODEL
# ### clf = classifier = to montelo<br>final_clf = to teliko model
#
# 1. dialegw
# 2. KANW FIT_TRANSFORM PANW SE TRAIN DATA X y

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

clf = RandomForestClassifier()

# list of dictionaries (1 dic)
param_grid = [
    {"n_estimators": [10,100,200,500], 
     "max_depth": [None,5,10], 
     "min_samples_split": [2,3,4]}
]

grid_search = GridSearchCV(clf, param_grid, cv=3, scoring="accuracy", return_train_score=True)
grid_search.fit(X_data,y_data)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid=[{'max_depth': [None, 5, 10],
#                           'min_samples_split': [2, 3, 4],
#                           'n_estimators': [10, 100, 200, 500]}],
#              return_train_score=True, scoring='accuracy')

# %%
final_clf = grid_search.best_estimator_
final_clf

# %% [markdown]
# # (E) EVALUATE
# efarmwzw transform (data processing) se TEST DATA (X+y mazi xwris split input/out)
#
# ta katharizw/etoimazw gia na ta valw sto model. dhladh vgazw axrhstes sthles, gemizw null koutia klp

# %%
strat_test_set = pipeline_object.fit_transform(strat_test_set)

# %%
X_test = strat_test_set.drop(["Survived"], axis=1)
y_test = strat_test_set["Survived"]

scaler = StandardScaler()
X_data_test = scaler.fit_transform(X_test)
y_data_test = y_test.to_numpy()

# %%
final_clf.score(X_data_test, y_data_test)
# Out:
# 0.8100558659217877

# %% [markdown]
# # (F) FINAL STEP
# ## ok twra exw to modelo(?)<br>1. βαζω μεσα test.csv<br>2. το φερνω σε μορφη X transformed<br>3. ftiaxnw y-hat column χρησμιοποιώντας model kai X

# %% [markdown]
# ### βαζω test.csv

# %%
titanic_test_data = pd.read_csv("../data/test.csv")

# %% [markdown]
# ### το φτιαχνω τωρα πριν STANDAD SCALER αλλαξει ["passengerID"]

# %%
final_df = pd.DataFrame(titanic_test_data["PassengerId"])

len(final_df)
# Out:
# 418

# %% [markdown]
# ### 1. pipeline<br>2. fillna με προηγουμενες τιμες (δουλευει σε καθε data type)<br>3. standardization (μ=0 σ=1)

# %%
titanic_test_data = pipeline_object.fit_transform(titanic_test_data)

titanic_test_data = titanic_test_data.fillna(method="ffill")

scaler = StandardScaler()
titanic_test_data = scaler.fit_transform(titanic_test_data)

# %%
predictions = final_clf.predict(titanic_test_data)

len(predictions)
# Out:
# 418

# %% [markdown]
# ### δημιουργω νεα στηλη "Suvrived" στον final_df<br>ftiaxnw csv

# %%
final_df["Survived"] = predictions

final_df.to_csv("../data/predictions.csv", index=False)

final_df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
